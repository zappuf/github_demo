# %%
from utils.math import generate_random_floats, visualize_normal_distribution

# %%
generate_random_floats(length = 10)
# Out:
# [1579.0000434104802,
#  1621.410572162236,
#  2181.6459084305043,
#  2054.481497501198,
#  1841.3940387452838,
#  606.8386757234193,
#  771.5367631697541,
#  1364.5948079117056,
#  413.42912971415626,
#  2707.244702090874]

# %%
visualize_normal_distribution(generate_random_floats(length=100))
